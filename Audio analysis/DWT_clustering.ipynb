# %%
import numpy as np
import scipy.io.wavfile as wavef
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import librosa.display as librosa
import librosa as librosa
import IPython.display as ipd
from IPython.display import Audio
from glob import glob
import umap
from sklearn.mixture import GaussianMixture
# import scipy.fft as fft
from scipy.fftpack import fft
from fastdtw import fastdtw
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-8e00173a84e4> in <module>
#      13 # import scipy.fft as fft
#      14 from scipy.fftpack import fft
# ---> 15 from fastdtw import fastdtw
#
# ModuleNotFoundError: No module named 'fastdtw'

# %%
## Load video and plot an example signal.
fileloc = glob("wav/*.wav")
wavs = [librosa.core.load(f, sr = None) for f in fileloc]

librosa.display.waveplot(wavs[6][0])

# %%
C1_cens = librosa.feature.chroma_cens(x1, sr=sr1, hop_length=hop_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-375e7384d125> in <module>
# ----> 1 C1_cens = librosa.feature.chroma_cens(x1, sr=sr1, hop_length=hop_length)
#
# NameError: name 'x1' is not defined

# %%
## Grab features using MFCCs
feature_size = 13
mfccs = []
for i in range(len(wavs)):
  mfccs.append(librosa.feature.mfcc(y=wavs[i][0], sr=wavs[i][1], n_mfcc = feature_size))

# %%
# Manipulate features for classifier
mfccs[3].shape
plt.plot(mfccs[1][1])
#librosa.display.waveplot(wavs[1][0])

# %%
# Manipulate the frame features.

# %%
## GMM or other classification model
gmm = GaussianMixture(n_components=6).fit(X)
labels = gmm.predict(X)
plot.scatter(X[:,0], X[:,1], c=labels, s =40, cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-66e2a6b2ebc4> in <module>()
#       1 ## GMM or other classification model
# ----> 2 gmm = GaussianMixture(n_components=6).fit(mfccs)
#       3 labels = gmm.predict(mfccs)
#       4 plot.scatter(mfccs[:,0], mfccs[:,1], c=labels, s =40, cmap='viridis')
#
# /usr/local/lib/python3.6/dist-packages/sklearn/mixture/_base.py in fit(self, X, y)
#     190         self
#     191         """
# --> 192         self.fit_predict(X, y)
#     193         return self
#     194
#
# /usr/local/lib/python3.6/dist-packages/sklearn/mixture/_base.py in fit_predict(self, X, y)
#     217             Component labels.
#     218         """
# --> 219         X = _check_X(X, self.n_components, ensure_min_samples=2)
#     220         self._check_initial_parameters(X)
#     221
#
# ...
